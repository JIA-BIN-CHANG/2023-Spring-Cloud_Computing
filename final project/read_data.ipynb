# %%
import pandas as pd

# %%
def get_date(df, year='YEAR', week='WEEK_NUM'):
    df = df.copy()
    df['formatted_date'] = df[year] * 1000 + df[week] * 10
    df['date'] = pd.to_datetime(df['formatted_date'], format='%Y%W%w')
    return df['date'].copy()

def read(dir_h, dir_t, dir_p):
    df_h = pd.read_csv(dir_h)
    df_t = pd.read_csv(dir_t)
    df_p = pd.read_csv(dir_p)

    # clean the tabs to space
    df_h.columns = [c.replace(' ', '') for c in df_h.columns]
    df_t.columns = [c.replace(' ', '') for c in df_t.columns]
    df_p.columns = [c.replace(' ', '') for c in df_p.columns]
    
    df_all = df_h.merge(df_t, on='HSHD_NUM', how='left').merge(df_p, on='PRODUCT_NUM', how='left')
    df_all.to_csv('data/all.csv')
    
    df_all = pd.read_csv('data/all.csv', index_col=0, low_memory=False)
    df_all['DATE'] = get_date(df_all)
    df_all = df_all.sort_values(['HSHD_NUM', 'BASKET_NUM', 'DATE', 'PRODUCT_NUM', 'DEPARTMENT', 'COMMODITY'], axis=0)
    df_display = df_all[['HSHD_NUM', 'BASKET_NUM', 'DATE', 'PRODUCT_NUM', 'DEPARTMENT', 'COMMODITY', 'SPEND', 'UNITS', 'STORE_R', 'WEEK_NUM', 'YEAR', 'L', 'AGE_RANGE', 'MARITAL', 'INCOME_RANGE', 'HOMEOWNER', 'HSHD_COMPOSITION', 'HH_SIZE', 'CHILDREN', 'PURCHASE_', 'BRAND_TY', 'NATURAL_ORGANIC_FLAG']]
    
    return df_display.copy()

# %%
# merge on HSHD and PRODUCT NUM
df_display = read('data/400_households.csv', 'data/400_transactions.csv', 'data/400_products.csv')
df_display.to_csv('data/all.csv', index=False)

# %%
df_display.head()
# Out:
#         HSHD_NUM  BASKET_NUM       DATE  PRODUCT_NUM  \
# 139820        10         281 2018-08-19       163380
# 138452        10         281 2018-08-19       248793
# 138737        10         281 2018-08-19       985784
# 139151        10         281 2018-08-19      1189945
# 139850        10         281 2018-08-19      2213539
#
#                         DEPARTMENT                   COMMODITY  SPEND  UNITS  \
# 139820  FOOD                        GROCERY STAPLE               2.29      1
# 138452  PHARMA                      MEDICATION                   7.99      1
# 138737  FOOD                        BAKERY                       2.49      1
# 139151  FOOD                        ALCOHOL                     12.99      1
# 139850  FOOD                        ALCOHOL                      4.49      1
#
#         STORE_R  WEEK_NUM  ...  \
# 139820  EAST           33  ...
# 138452  EAST           33  ...
# 138737  EAST           33  ...
# 139151  EAST           33  ...
# 139850  EAST           33  ...
#
#                                                 AGE_RANGE  MARITAL  \
# 139820  45-54                                         ...  Single
# 138452  45-54                                         ...  Single
# 138737  45-54                                         ...  Single
# 139151  45-54                                         ...  Single
# 139850  45-54                                         ...  Single
#
#                                              INCOME_RANGE  HOMEOWNER  \
# 139820  35-49K                                        ...  Homeowner
# 138452  35-49K                                        ...  Homeowner
# 138737  35-49K                                        ...  Homeowner
# 139151  35-49K                                        ...  Homeowner
# 139850  35-49K                                        ...  Homeowner
#
#          HSHD_COMPOSITION                                            HH_SIZE  \
# 139820  1 Adult            1                                             ...
# 138452  1 Adult            1                                             ...
# 138737  1 Adult            1                                             ...
# 139151  1 Adult            1                                             ...
# 139850  1 Adult            1                                             ...
#
#        CHILDREN  PURCHASE_  BRAND_TY NATURAL_ORGANIC_FLAG
# 139820      NaN  19-AUG-18  NATIONAL                    N
# 138452      NaN  19-AUG-18  NATIONAL                    N
# 138737      NaN  19-AUG-18  NATIONAL                    N
# 139151      NaN  19-AUG-18  NATIONAL                    N
# 139850      NaN  19-AUG-18  NATIONAL                    N
#
# [5 rows x 22 columns]
